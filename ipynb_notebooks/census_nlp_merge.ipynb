# %%
import seaborn as sns;
import matplotlib.pyplot as plt;
import pandas as pd;
import numpy as np;
import os;
import time;
import datetime;
# %matplotlib inline

# %%
df_left = pd.read_csv('table_subtable1_totals.csv').drop(columns = ['Unnamed: 0', 'subtable_headers'])
df_left
# Out:
#                     Counties  Year time_period Under 5 years 5 to 9 years  \
# 0       Colusa County (5 YR)  2016          5Y         7.40%        7.80%
# 1       Colusa County (5 YR)  2012          5Y         7.40%        7.80%
# 2           Glenn County, CA  2016          5Y         8.60%        8.40%
# 3           Glenn County, CA  2012          5Y         7.30%        7.10%
# 4    Del Norte County (5 YR)  2016          5Y         7.50%        6.40%
# ..                       ...   ...         ...           ...          ...
# 187          Yuba County, CA  2012          5Y         8.30%        8.10%
# 188     San Francisco County  2016          1Y         8.50%        7.90%
# 189     San Francisco County  2012          1Y         6.10%        6.30%
# 190     San Francisco County  2012          5Y         6.30%        6.50%
# 191     San Francisco County  2016          5Y         4.40%        3.50%
#
#     10 to 14 years 15 to 19 years 20 to 24 years 25 to 29 years  \
# ...

# %%
# %ls
# Out:
# sample_data/  table_subtable1_totals.csv  winner_labels.csv

# %%
#df_right = pd.read_csv('winner_correlator_labels (2).csv').drop(columns = ['Unnamed: 0'])
df_right = pd.read_csv('winner_labels.csv').drop(columns = ['Unnamed: 0'])

df_right
# Out:
#                     Counties  Year winning_candidate  winner_vote_percent  \
# 0             Alameda County  2016   Hillary Clinton                 78.7
# 1       Alpine County (5 YR)  2016   Hillary Clinton                 55.5
# 2       Amador County (5 YR)  2016      Donald Trump                 59.1
# 3               Butte County  2016      Donald Trump                 47.2
# 4    Calaveras County (5 YR)  2016      Donald Trump                 58.4
# ..                       ...   ...               ...                  ...
# 107        Tulare County, CA  2012       Mitt Romney                 56.3
# 108      Tuolumne County, CA  2012       Mitt Romney                 56.2
# 109       Ventura County, CA  2012      Barack Obama                 52.3
# 110          Yolo County, CA  2012      Barack Obama                 65.4
# 111          Yuba County, CA  2012       Mitt Romney                 57.2
#
#                    ideological_label
# 0         Liberal\nParty Affiliation
# ...

# %%
df_right['ideological_label'] = df_right['ideological_label'].apply(lambda x: x.split('\n')[0])
df_right['ideological_label']
# Out:
# 0                    Liberal
# 1                    Liberal
# 2      Populist Conservative
# 3      Populist Conservative
# 4      Populist Conservative
#                ...
# 107             Conservative
# 108             Conservative
# 109      Liberal/Progressive
# 110      Liberal/Progressive
# 111             Conservative
# Name: ideological_label, Length: 112, dtype: object

# %%
df_left = df_left[df_left['time_period'] == '5Y']

# %%
### NOTE: MISSING SAN FRANCISCO DUE TO OLDER CSV USE!!!
df = df_left.merge(df_right, how = 'inner')

# %%
set(df_left["Counties"]).difference(df_right['Counties'])
# Out:
# {'San Francisco County'}

# %% [markdown]
# SF is missing in right column

# %%
set(df_right["Counties"]).difference(df_left['Counties'])
# Out:
# set()

# %%
df_right
# Out:
#                     Counties  Year winning_candidate  winner_vote_percent  \
# 0             Alameda County  2016   Hillary Clinton                 78.7
# 1       Alpine County (5 YR)  2016   Hillary Clinton                 55.5
# 2       Amador County (5 YR)  2016      Donald Trump                 59.1
# 3               Butte County  2016      Donald Trump                 47.2
# 4    Calaveras County (5 YR)  2016      Donald Trump                 58.4
# ..                       ...   ...               ...                  ...
# 107        Tulare County, CA  2012       Mitt Romney                 56.3
# 108      Tuolumne County, CA  2012       Mitt Romney                 56.2
# 109       Ventura County, CA  2012      Barack Obama                 52.3
# 110          Yolo County, CA  2012      Barack Obama                 65.4
# 111          Yuba County, CA  2012       Mitt Romney                 57.2
#
#          ideological_label
# 0                  Liberal
# ...

# %%
df
# Out:
#                     Counties  Year time_period Under 5 years 5 to 9 years  \
# 0       Colusa County (5 YR)  2016          5Y         7.40%        7.80%
# 1       Colusa County (5 YR)  2012          5Y         7.40%        7.80%
# 2           Glenn County, CA  2016          5Y         8.60%        8.40%
# 3           Glenn County, CA  2012          5Y         7.30%        7.10%
# 4    Del Norte County (5 YR)  2016          5Y         7.50%        6.40%
# ..                       ...   ...         ...           ...          ...
# 105        Sonoma County, CA  2012          5Y         5.30%        5.80%
# 106       Ventura County, CA  2012          5Y         6.60%        7.10%
# 107       Ventura County, CA  2016          5Y         6.70%        7.00%
# 108          Yuba County, CA  2016          5Y         7.60%        8.70%
# 109          Yuba County, CA  2012          5Y         8.30%        8.10%
#
#     10 to 14 years 15 to 19 years 20 to 24 years 25 to 29 years  \
# ...

# %%
df.to_csv('merged_total_census_party.csv')
